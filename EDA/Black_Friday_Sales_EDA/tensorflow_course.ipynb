# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaybabu1992/Black_Friday_Sales_EDA/blob/main/tensorflow_course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import sklearn as sk
import sklearn.datasets as ds

# %%
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)
model.fit(xs, ys, epochs=500)
print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 526ms/step - loss: 11.1801
# Epoch 2/500
# 1/1 [==============================] - 0s 15ms/step - loss: 9.0141
# Epoch 3/500
# 1/1 [==============================] - 0s 14ms/step - loss: 7.3055
# Epoch 4/500
# 1/1 [==============================] - 0s 13ms/step - loss: 5.9569
# Epoch 5/500
# 1/1 [==============================] - 0s 15ms/step - loss: 4.8916
# Epoch 6/500
# 1/1 [==============================] - 0s 17ms/step - loss: 4.0492
# Epoch 7/500
# 1/1 [==============================] - 0s 14ms/step - loss: 3.3824
# Epoch 8/500
# 1/1 [==============================] - 0s 12ms/step - loss: 2.8537
# Epoch 9/500
# 1/1 [==============================] - 0s 12ms/step - loss: 2.4338
# Epoch 10/500
# 1/1 [==============================] - 0s 11ms/step - loss: 2.0995
# Epoch 11/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.8328
# Epoch 12/500
# ...
